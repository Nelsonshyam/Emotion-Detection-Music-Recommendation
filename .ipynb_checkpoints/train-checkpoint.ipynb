# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from keras.models import Sequential 
from tensorflow.keras.preprocessing import image
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import cv2

# %%
img_path = "data/train/angry/Training_10118481.jpg"
img = image.load_img(img_path)

# %%
plt.imshow(img)
plt.show()

# %%
img_path = "data/train/angry/Training_10118481.jpg"
cv2.imread(img_path).shape
# Out:
# (48, 48, 3)

# %%
train_dir = 'data/train' 
test_dir = 'data/test'

# %%
img_size = (48, 48) 
batch_size = 32
num_classes = 7

# %%
train_datagen = ImageDataGenerator(width_shift_range = 0.1,
                                   height_shift_range = 0.1,
                                   horizontal_flip = True,
                                   rescale = 1./255,
                                   zoom_range = 0.2,
                                   validation_split = 0.2)
test_datagen = ImageDataGenerator(rescale = 1./255,)

# %%
train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = img_size,
                                                    batch_size = batch_size,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical"
                                                   )
test_generator = test_datagen.flow_from_directory( directory = test_dir,
                                                              target_size = img_size,
                                                              batch_size = batch_size,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical",
                                                             )
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
def build_model(input_shape, num_classes):
    model = Sequential([
        layers.Input(shape=input_shape),
        Conv2D(32,(3,3),padding='same',activation='relu'),
        Conv2D(64,(3,3),padding='same',activation='relu'),
        BatchNormalization(),
        MaxPool2D(pool_size=(2, 2)),
        Dropout(0.25),

        Conv2D(128,(3,3),padding='same',activation='relu'),
        Conv2D(256,(3,3),padding='same',activation='relu'),
        BatchNormalization(),
        MaxPool2D(pool_size=(2, 2)),
        Dropout(0.25),

        Conv2D(256,(3,3),padding='same',activation='relu'),
        BatchNormalization(),
        MaxPool2D(pool_size=(2, 2)),
        Dropout(0.25),

        Flatten(),

        Dense(100,activation = 'relu'),

        Dense(50,activation = 'relu'),

        Dense(225,activation = 'relu'),

        BatchNormalization(),
        Dropout(0.25),

        Dense(7, activation='softmax')
    ])
    return model

# %%
model = build_model((48, 48, 1), num_classes)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 48, 48, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 48, 48, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 24, 24, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 24, 24, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 24, 24, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 12, 12, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 9216)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 100)                 │         921,700 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 50)                  │           5,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 225)                 │          11,475 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 225)                 │             900 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 225)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 7)                   │           1,582 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,920,931 (7.33 MB)
#  Trainable params: 1,919,329 (7.32 MB)
#  Non-trainable params: 1,602 (6.26 KB)

# %%
model.compile(
    optimizer = optimizers.Adam(learning_rate=0.00025), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
  )

# %%
lr_schedule = callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, verbose=1)
early_stopping = callbacks.EarlyStopping(monitor='val_accuracy', patience=8, restore_best_weights=True, verbose=1)
checkpoint = callbacks.ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
history = model.fit(
    train_generator,
    epochs=55,  
    validation_data=test_generator,
    callbacks=[lr_schedule, early_stopping, checkpoint]
)
# Out:
# C:\Users\nelso\anaconda3\envs\notebook-6.5.7_1\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.2031 - loss: 2.1060
# Epoch 1: val_accuracy improved from -inf to 0.22820, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 715s 789ms/step - accuracy: 0.2031 - loss: 2.1059 - val_accuracy: 0.2282 - val_loss: 2.1207 - learning_rate: 2.5000e-04
# Epoch 2/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.3148 - loss: 1.7707
# Epoch 2: val_accuracy improved from 0.22820 to 0.45444, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 433s 483ms/step - accuracy: 0.3148 - loss: 1.7707 - val_accuracy: 0.4544 - val_loss: 1.4448 - learning_rate: 2.5000e-04
# Epoch 3/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.4013 - loss: 1.5490
# Epoch 3: val_accuracy improved from 0.45444 to 0.48398, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 331s 369ms/step - accuracy: 0.4013 - loss: 1.5490 - val_accuracy: 0.4840 - val_loss: 1.3606 - learning_rate: 2.5000e-04
# Epoch 4/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.4583 - loss: 1.4082
# Epoch 4: val_accuracy improved from 0.48398 to 0.51714, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 341s 380ms/step - accuracy: 0.4583 - loss: 1.4082 - val_accuracy: 0.5171 - val_loss: 1.2820 - learning_rate: 2.5000e-04
# Epoch 5/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.4945 - loss: 1.3213
# Epoch 5: val_accuracy improved from 0.51714 to 0.54723, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 476s 530ms/step - accuracy: 0.4945 - loss: 1.3213 - val_accuracy: 0.5472 - val_loss: 1.2039 - learning_rate: 2.5000e-04
# Epoch 6/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.5205 - loss: 1.2533
# Epoch 6: val_accuracy did not improve from 0.54723
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 448s 499ms/step - accuracy: 0.5205 - loss: 1.2533 - val_accuracy: 0.5432 - val_loss: 1.2046 - learning_rate: 2.5000e-04
# Epoch 7/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.5395 - loss: 1.2226
# Epoch 7: val_accuracy improved from 0.54723 to 0.55614, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 415s 462ms/step - accuracy: 0.5395 - loss: 1.2226 - val_accuracy: 0.5561 - val_loss: 1.1766 - learning_rate: 2.5000e-04
# Epoch 8/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.5498 - loss: 1.1944
# Epoch 8: val_accuracy improved from 0.55614 to 0.58429, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 357s 398ms/step - accuracy: 0.5498 - loss: 1.1944 - val_accuracy: 0.5843 - val_loss: 1.0982 - learning_rate: 2.5000e-04
# Epoch 9/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5656 - loss: 1.1529
# Epoch 9: val_accuracy did not improve from 0.58429
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 356s 396ms/step - accuracy: 0.5656 - loss: 1.1529 - val_accuracy: 0.5628 - val_loss: 1.1589 - learning_rate: 2.5000e-04
# Epoch 10/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.5685 - loss: 1.1379
# Epoch 10: val_accuracy improved from 0.58429 to 0.60240, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 436s 485ms/step - accuracy: 0.5685 - loss: 1.1379 - val_accuracy: 0.6024 - val_loss: 1.0429 - learning_rate: 2.5000e-04
# Epoch 11/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.5881 - loss: 1.1009
# Epoch 11: val_accuracy improved from 0.60240 to 0.61048, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 440s 490ms/step - accuracy: 0.5881 - loss: 1.1009 - val_accuracy: 0.6105 - val_loss: 1.0389 - learning_rate: 2.5000e-04
# Epoch 12/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.5962 - loss: 1.0868
# Epoch 12: val_accuracy did not improve from 0.61048
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 376s 419ms/step - accuracy: 0.5962 - loss: 1.0868 - val_accuracy: 0.6074 - val_loss: 1.0413 - learning_rate: 2.5000e-04
# Epoch 13/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.6003 - loss: 1.0649
# Epoch 13: val_accuracy did not improve from 0.61048
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 366s 407ms/step - accuracy: 0.6003 - loss: 1.0649 - val_accuracy: 0.6002 - val_loss: 1.0787 - learning_rate: 2.5000e-04
# Epoch 14/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.6002 - loss: 1.0687
# Epoch 14: val_accuracy improved from 0.61048 to 0.61758, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 416s 464ms/step - accuracy: 0.6002 - loss: 1.0687 - val_accuracy: 0.6176 - val_loss: 1.0075 - learning_rate: 2.5000e-04
# Epoch 15/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.6075 - loss: 1.0432
# Epoch 15: val_accuracy improved from 0.61758 to 0.61884, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 437s 487ms/step - accuracy: 0.6075 - loss: 1.0432 - val_accuracy: 0.6188 - val_loss: 1.0164 - learning_rate: 2.5000e-04
# Epoch 16/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.6149 - loss: 1.0381
# Epoch 16: val_accuracy did not improve from 0.61884
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 436s 486ms/step - accuracy: 0.6149 - loss: 1.0381 - val_accuracy: 0.5999 - val_loss: 1.1178 - learning_rate: 2.5000e-04
# Epoch 17/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.6226 - loss: 1.0257
# Epoch 17: val_accuracy improved from 0.61884 to 0.62051, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 439s 489ms/step - accuracy: 0.6226 - loss: 1.0257 - val_accuracy: 0.6205 - val_loss: 0.9966 - learning_rate: 2.5000e-04
# Epoch 18/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.6212 - loss: 1.0082
# Epoch 18: val_accuracy improved from 0.62051 to 0.62594, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 447s 497ms/step - accuracy: 0.6212 - loss: 1.0082 - val_accuracy: 0.6259 - val_loss: 1.0141 - learning_rate: 2.5000e-04
# Epoch 19/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.6312 - loss: 0.9905
# Epoch 19: val_accuracy improved from 0.62594 to 0.62692, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 531s 592ms/step - accuracy: 0.6312 - loss: 0.9905 - val_accuracy: 0.6269 - val_loss: 1.0155 - learning_rate: 2.5000e-04
# Epoch 20/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.6271 - loss: 0.9965
# Epoch 20: val_accuracy improved from 0.62692 to 0.62928, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 557s 620ms/step - accuracy: 0.6271 - loss: 0.9965 - val_accuracy: 0.6293 - val_loss: 1.0170 - learning_rate: 2.5000e-04
# Epoch 21/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.6347 - loss: 0.9709
# Epoch 21: val_accuracy did not improve from 0.62928
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 438s 488ms/step - accuracy: 0.6347 - loss: 0.9709 - val_accuracy: 0.5874 - val_loss: 1.1259 - learning_rate: 2.5000e-04
# Epoch 22/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.6405 - loss: 0.9630
# Epoch 22: val_accuracy did not improve from 0.62928
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 444s 494ms/step - accuracy: 0.6405 - loss: 0.9630 - val_accuracy: 0.6241 - val_loss: 1.0068 - learning_rate: 2.5000e-04
# Epoch 23/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.6459 - loss: 0.9495
# Epoch 23: val_accuracy improved from 0.62928 to 0.64043, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 484s 539ms/step - accuracy: 0.6459 - loss: 0.9495 - val_accuracy: 0.6404 - val_loss: 0.9701 - learning_rate: 2.5000e-04
# Epoch 24/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.6440 - loss: 0.9620
# Epoch 24: val_accuracy did not improve from 0.64043
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 442s 492ms/step - accuracy: 0.6440 - loss: 0.9620 - val_accuracy: 0.6230 - val_loss: 1.0084 - learning_rate: 2.5000e-04
# Epoch 25/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.6404 - loss: 0.9588
# Epoch 25: val_accuracy did not improve from 0.64043
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 434s 483ms/step - accuracy: 0.6404 - loss: 0.9588 - val_accuracy: 0.6343 - val_loss: 0.9889 - learning_rate: 2.5000e-04
# Epoch 26/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.6520 - loss: 0.9289
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 26: val_accuracy did not improve from 0.64043
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 392s 436ms/step - accuracy: 0.6520 - loss: 0.9289 - val_accuracy: 0.6339 - val_loss: 1.0052 - learning_rate: 2.5000e-04
# Epoch 27/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.6543 - loss: 0.9187
# Epoch 27: val_accuracy improved from 0.64043 to 0.65673, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 416s 464ms/step - accuracy: 0.6543 - loss: 0.9187 - val_accuracy: 0.6567 - val_loss: 0.9407 - learning_rate: 1.2500e-04
# Epoch 28/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.6670 - loss: 0.8885
# Epoch 28: val_accuracy did not improve from 0.65673
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 386s 430ms/step - accuracy: 0.6670 - loss: 0.8885 - val_accuracy: 0.6539 - val_loss: 0.9407 - learning_rate: 1.2500e-04
# Epoch 29/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.6707 - loss: 0.8802
# Epoch 29: val_accuracy improved from 0.65673 to 0.65882, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 361s 402ms/step - accuracy: 0.6707 - loss: 0.8802 - val_accuracy: 0.6588 - val_loss: 0.9417 - learning_rate: 1.2500e-04
# Epoch 30/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6730 - loss: 0.8782
# Epoch 30: val_accuracy did not improve from 0.65882
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 356s 397ms/step - accuracy: 0.6730 - loss: 0.8782 - val_accuracy: 0.6553 - val_loss: 0.9514 - learning_rate: 1.2500e-04
# Epoch 31/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6793 - loss: 0.8649
# Epoch 31: val_accuracy improved from 0.65882 to 0.66467, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 363s 404ms/step - accuracy: 0.6793 - loss: 0.8649 - val_accuracy: 0.6647 - val_loss: 0.9306 - learning_rate: 1.2500e-04
# Epoch 32/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.6784 - loss: 0.8616
# Epoch 32: val_accuracy did not improve from 0.66467
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 415s 462ms/step - accuracy: 0.6784 - loss: 0.8616 - val_accuracy: 0.6601 - val_loss: 0.9355 - learning_rate: 1.2500e-04
# Epoch 33/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.6845 - loss: 0.8491
# Epoch 33: val_accuracy did not improve from 0.66467
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 365s 407ms/step - accuracy: 0.6845 - loss: 0.8491 - val_accuracy: 0.6553 - val_loss: 0.9424 - learning_rate: 1.2500e-04
# Epoch 34/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.6857 - loss: 0.8531
# Epoch 34: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 34: val_accuracy did not improve from 0.66467
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 365s 406ms/step - accuracy: 0.6857 - loss: 0.8531 - val_accuracy: 0.6573 - val_loss: 0.9575 - learning_rate: 1.2500e-04
# Epoch 35/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.6949 - loss: 0.8269
# Epoch 35: val_accuracy improved from 0.66467 to 0.66982, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 450s 501ms/step - accuracy: 0.6949 - loss: 0.8269 - val_accuracy: 0.6698 - val_loss: 0.9198 - learning_rate: 6.2500e-05
# Epoch 36/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.6975 - loss: 0.8179
# Epoch 36: val_accuracy did not improve from 0.66982
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 433s 482ms/step - accuracy: 0.6975 - loss: 0.8179 - val_accuracy: 0.6675 - val_loss: 0.9280 - learning_rate: 6.2500e-05
# Epoch 37/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.6998 - loss: 0.8150
# Epoch 37: val_accuracy did not improve from 0.66982
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 405s 451ms/step - accuracy: 0.6998 - loss: 0.8150 - val_accuracy: 0.6638 - val_loss: 0.9376 - learning_rate: 6.2500e-05
# Epoch 38/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6993 - loss: 0.8172
# Epoch 38: val_accuracy improved from 0.66982 to 0.67122, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 367s 409ms/step - accuracy: 0.6993 - loss: 0.8172 - val_accuracy: 0.6712 - val_loss: 0.9253 - learning_rate: 6.2500e-05
# Epoch 39/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.7098 - loss: 0.7845
# Epoch 39: val_accuracy improved from 0.67122 to 0.67400, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 428s 477ms/step - accuracy: 0.7098 - loss: 0.7845 - val_accuracy: 0.6740 - val_loss: 0.9291 - learning_rate: 6.2500e-05
# Epoch 40/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.7047 - loss: 0.8047
# Epoch 40: val_accuracy did not improve from 0.67400
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 461s 513ms/step - accuracy: 0.7047 - loss: 0.8047 - val_accuracy: 0.6675 - val_loss: 0.9519 - learning_rate: 6.2500e-05
# Epoch 41/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.7035 - loss: 0.7987
# Epoch 41: val_accuracy did not improve from 0.67400
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 529s 589ms/step - accuracy: 0.7035 - loss: 0.7987 - val_accuracy: 0.6739 - val_loss: 0.9282 - learning_rate: 6.2500e-05
# Epoch 42/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.7118 - loss: 0.7888
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 42: val_accuracy did not improve from 0.67400
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 383s 427ms/step - accuracy: 0.7118 - loss: 0.7888 - val_accuracy: 0.6722 - val_loss: 0.9155 - learning_rate: 6.2500e-05
# Epoch 43/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.7137 - loss: 0.7842
# Epoch 43: val_accuracy improved from 0.67400 to 0.67693, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 374s 416ms/step - accuracy: 0.7137 - loss: 0.7842 - val_accuracy: 0.6769 - val_loss: 0.9100 - learning_rate: 3.1250e-05
# Epoch 44/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.7114 - loss: 0.7793
# Epoch 44: val_accuracy did not improve from 0.67693
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 364s 405ms/step - accuracy: 0.7114 - loss: 0.7793 - val_accuracy: 0.6743 - val_loss: 0.9157 - learning_rate: 3.1250e-05
# Epoch 45/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.7132 - loss: 0.7792
# Epoch 45: val_accuracy improved from 0.67693 to 0.67790, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 460s 513ms/step - accuracy: 0.7132 - loss: 0.7792 - val_accuracy: 0.6779 - val_loss: 0.9086 - learning_rate: 3.1250e-05
# Epoch 46/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.7161 - loss: 0.7776
# Epoch 46: val_accuracy did not improve from 0.67790
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 391s 435ms/step - accuracy: 0.7161 - loss: 0.7776 - val_accuracy: 0.6729 - val_loss: 0.9379 - learning_rate: 3.1250e-05
# Epoch 47/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.7203 - loss: 0.7643
# Epoch 47: val_accuracy did not improve from 0.67790
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 368s 410ms/step - accuracy: 0.7203 - loss: 0.7644 - val_accuracy: 0.6765 - val_loss: 0.9165 - learning_rate: 3.1250e-05
# Epoch 48/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.7185 - loss: 0.7726
# Epoch 48: val_accuracy improved from 0.67790 to 0.67930, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 372s 415ms/step - accuracy: 0.7185 - loss: 0.7726 - val_accuracy: 0.6793 - val_loss: 0.9115 - learning_rate: 3.1250e-05
# Epoch 49/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.7186 - loss: 0.7692
# Epoch 49: val_accuracy did not improve from 0.67930
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 473s 526ms/step - accuracy: 0.7186 - loss: 0.7692 - val_accuracy: 0.6755 - val_loss: 0.9246 - learning_rate: 3.1250e-05
# Epoch 50/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.7224 - loss: 0.7572
# Epoch 50: val_accuracy did not improve from 0.67930
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 415s 462ms/step - accuracy: 0.7224 - loss: 0.7572 - val_accuracy: 0.6767 - val_loss: 0.9380 - learning_rate: 3.1250e-05
# Epoch 51/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.7234 - loss: 0.7638
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 51: val_accuracy did not improve from 0.67930
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 357s 397ms/step - accuracy: 0.7234 - loss: 0.7638 - val_accuracy: 0.6754 - val_loss: 0.9104 - learning_rate: 3.1250e-05
# Epoch 52/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.7191 - loss: 0.7678
# Epoch 52: val_accuracy improved from 0.67930 to 0.68194, saving model to best_model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 521s 580ms/step - accuracy: 0.7191 - loss: 0.7678 - val_accuracy: 0.6819 - val_loss: 0.9006 - learning_rate: 1.5625e-05
# Epoch 53/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7225 - loss: 0.7529
# Epoch 53: val_accuracy did not improve from 0.68194
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 524s 584ms/step - accuracy: 0.7225 - loss: 0.7529 - val_accuracy: 0.6780 - val_loss: 0.9163 - learning_rate: 1.5625e-05
# Epoch 54/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.7230 - loss: 0.7500
# Epoch 54: val_accuracy did not improve from 0.68194
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 412s 459ms/step - accuracy: 0.7230 - loss: 0.7500 - val_accuracy: 0.6790 - val_loss: 0.9132 - learning_rate: 1.5625e-05
# Epoch 55/55
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.7245 - loss: 0.7515
# Epoch 55: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 55: val_accuracy did not improve from 0.68194
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 359s 399ms/step - accuracy: 0.7245 - loss: 0.7515 - val_accuracy: 0.6776 - val_loss: 0.9160 - learning_rate: 1.5625e-05
# Restoring model weights from the end of the best epoch: 52.

# %%
test_labels = []
for i in range(len(test_generator)):
    _, labels = next(test_generator)
    test_labels.extend(np.argmax(labels, axis=1))  

test_labels = np.array(test_labels)

predictions = np.argmax(model.predict(test_generator, verbose=1), axis=1)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 24s 104ms/step

# %%
train_generator.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
class_names = list(train_generator.class_indices.keys())
class_names
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
print("Classification report:\n",classification_report(test_labels, predictions,target_names=class_names))
print("Confusion matrix:\n",confusion_matrix(test_labels, predictions))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#        angry       0.60      0.62      0.61       958
#      disgust       0.70      0.52      0.60       111
#         fear       0.60      0.41      0.48      1024
#        happy       0.87      0.88      0.87      1774
#      neutral       0.56      0.74      0.64      1233
#          sad       0.59      0.55      0.57      1247
#     surprise       0.80      0.82      0.81       831
#
#     accuracy                           0.68      7178
#    macro avg       0.67      0.65      0.65      7178
# weighted avg       0.68      0.68      0.68      7178
#
# Confusion matrix:
#  [[ 593   14   66   32  128  112   13]
#  [  33   58    3    2    6    7    2]
#  [ 131    5  415   29  155  193   96]
#  [  25    2   15 1560  115   30   27]
#  [  59    3   43   77  910  126   15]
#  [ 122    0   96   51  276  680   22]
#  [  19    1   57   44   23    8  679]]

# %%
cm = confusion_matrix(test_labels, predictions)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
score = model.evaluate(test_generator,verbose=0)
print("Test loss:",round(score[0],3))
print("Test accuracy:",round(score[1],2))
# Out:
# Test loss: 0.9
# Test accuracy: 0.68

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# %%
model.save("My_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
